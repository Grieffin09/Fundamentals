# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2021-05-07', periods=1000),columns=['value'])
ts=pd.Series(randn(1000),index=pd.date_range('2021-05-07',periods=1000))

# %%
df.head()
# Out:
#                value
# 2021-05-07 -2.765252
# 2021-05-08  0.441956
# 2021-05-09  1.088520
# 2021-05-10  0.482784
# 2021-05-11 -1.635308

# %%
ts.plot()
# Out:
# <Axes: >

# %%
ts=ts.cumsum()
ts
# Out:
# 2021-05-07    -0.566059
# 2021-05-08    -0.778194
# 2021-05-09    -1.615968
# 2021-05-10    -3.617018
# 2021-05-11    -2.980356
#                 ...
# 2024-01-27   -39.356575
# 2024-01-28   -38.658085
# 2024-01-29   -39.195509
# 2024-01-30   -35.507994
# 2024-01-31   -36.236611
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <Axes: >

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax=iris.plot(figsize=(15,8),title='Iris Dataset')
ax.set_ylabel('Y-axis')
ax.set_xlabel('X-axis')
# Out:
# Text(0.5, 0, 'X-axis')

# %%
ts.plot(figsize=(100,70),kind='bar')
# Out:
# <Axes: >

# %%
df=iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <Axes: >

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='barh')
# Out:
# <Axes: >

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

df.plot.bar()
# Out:
# <Axes: >

# %%
iris.plot(kind='hist',stacked=False,bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.diff().hist(color='y',alpha=1,figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'c'}>, <Axes: title={'center': 'd'}>]],
#       dtype=object)

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c="sepal_width",s=100)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.hexbin(x='sepal_length',y='petal_length',gridsize=20,C='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
ir=iris.iloc[0]
ir.plot.pie(figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 ir=iris.iloc[0]
# ----> 2 ir.plot.pie(figsize=(10,10))
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
iris.drop(['species'],axis=1,inplace=True)

# %%
ir=iris.iloc[0]
ir.plot.pie(figsize=(10,10))
# Out:
# <Axes: ylabel='0'>

# %%
iri=iris.head(3).T
iri
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iri.plot.pie(subplots=True,figsize=(30,30),fontsize=22,autopct='%.2f')
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris,figsize=(8,8),diagonal='kde',color='r')
plt.show()

# %%
iris['petal_length'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(iris,'sepal_length')
# Out:
# <Axes: >

# %%
iris.plot(legend=True,figsize=(10,5),logy=True)
# Out:
# <Axes: >

# %%
ts.plot(style='r+',label='Series',legend=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ts.plot(style='r@',label='Series',legend=True)
#
# NameError: name 'ts' is not defined

# %%
iris.plot(legend=True,figsize=(10,5),logy=True,subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
iris.plot(subplots=True,sharex=False,layout=(4,2),figsize=(10,8))
plt.tight_layout()
